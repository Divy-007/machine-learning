# %%
import pandas as pd
import seaborn as sns

# %%
titanic=pd.read_csv('tested.csv')
iris=pd.read_csv('iris.csv')
tips=pd.read_csv('tip.csv')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### 1.scatterplot

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips, hue='sex', style='smoker',size='size'
               )
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# #### anaylsis ->The scatter plot shows a clear positive correlation between total bill and tip amount — higher bills usually lead to higher tips. Males tend to tip more generously than females, both in frequency and value. Interestingly, the highest tip was given by a smoker, suggesting that social habits may influence tipping behavior. Overall, spending level, gender, and smoking status all appear to play a role in how customers tip.

# %% [markdown]
# ### 2. scatter plot

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
sns.barplot(x='Pclass',y='Fare' , data=titanic , hue='Survived' )
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %% [markdown]
# #### anaylsis ->  this scatter plot shows the survival rate based on the customer pclass . its shows who pays the more fair in all class  have the more chance of survivng.
