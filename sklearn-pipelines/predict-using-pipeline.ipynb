# %%
import pandas as pd 
import numpy as np 
import seaborn as sns

# %%
import pickle

# %%
pipe = pickle.load(open('pipe.pkl','rb'))

# %%
# Assume user input
test_input2 = np.array([3, 'male', 15.0, 0, 0, 10.5, 'Q'],dtype=object).reshape(1,7)

# %%
pipe.predict(test_input2)
# Out:
# D:\new folder\envs\py312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# D:\new folder\envs\py312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([1])
